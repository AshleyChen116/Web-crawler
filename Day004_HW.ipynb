# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"13146646538","type":"IssueCommentEvent","actor":{"id":1044766,"login":"behrmann","display_login":"behrmann","gravatar_id":"","url":"https://api.github.com/users/behrmann","avatar_url":"https://avatars.githubusercontent.com/u/1044766?"},"repo":{"id":63237385,"name":"systemd/mkosi","url":"https://api.github.com/repos/systemd/mkosi"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/systemd/mkosi/issues/490","repository_url":"https://api.github.com/repos/systemd/mkosi","labels_url":"https://api.github.com/repos/systemd/mkosi/issues/490/labels{/name}","comments_url":"https://api.github.com/repos/systemd/mkosi/issues/490/comments","events_url":"https://api.github.com/repos/systemd/mkosi/issues/490/events","html_url":"https://github.com/systemd/mkosi/pull/490","id":672270824,"node_id":"MDExOlB1bGxSZXF1ZXN0NDYyMzM3NzIz","number":490,"title":"Unified kernel images improvements","user":{"login":"DaanDeMeyer","id":9395011,"node_id":"MDQ6VXNlcjkzOTUwMTE=","avatar_url":"https://avatars3.githubusercontent.com/u/9395011?v=4","gravatar_id":"","url":"https://api.github.com/users/DaanDeMeyer","html_url":"https://github.com/DaanDeMeyer","followers_url":"https://api.github.com/users/DaanDeMeyer/followers","following_url":"https://api.github.com/users/DaanDeMeyer/following{/other_user}","gists_url":"https://api.github.com/users/DaanDeMeyer/gists{/gist_id}","starred_url":"https://api.github.com/users/DaanDeMeyer/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/DaanDeMeyer/subscriptions","organizations_url":"https://api.github.com/users/DaanDeMeyer/orgs","repos_url":"https://api.github.com/users/DaanDeMeyer/repos","events_url":"https://api.github.com/users/DaanDeMeyer/events{/privacy}","received_events_url":"https://api.github.com/users/DaanDeMeyer/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":23,"created_at":"2020-08-03T18:44:48Z","updated_at":"2020-08-08T11:08:51Z","closed_at":null,"author_association":"CONTRIBUTOR","active_lock_reason":null,"pull_request":{"url":"https://api.github.com/repos/systemd/mkosi/pulls/490","html_url":"https://github.com/systemd/mkosi/pull/490","diff_url":"https://github.com/systemd/mkosi/pull/490.diff","patch_url":"https://github.com/systemd/mkosi/pull/490.patch"},"body":"Doing the initial kernel installs with kernel-install and the rest with mkinitcpio is weird. Let\'s just use kernel-install all the time. Rest of the commits are simplification of the existing logic.\\r\\n\\r\\nI also want to add unified kernel images support for Arch but I want to accompany that with a flag to disable unified kernel images (which I really think should be the default but that breaks backwards compat)","performed_via_github_app":null},"comment":{"url":"https://api.github.com/repos/systemd/mkosi/issues/comments/670896166","html_url":"https://github.com/systemd/mkosi/pull/490#issuecomment-670896166","issue_url":"https://api.github.com/repos/systemd/mkosi/issues/490","id":670896166,"node_id":"MDEyOklzc3VlQ29tbWVudDY3MDg5NjE2Ng==","user":{"login":"behrmann","id":1044766,"node_id":"MDQ6VXNlcjEwNDQ3NjY=","avatar_url":"https://avatars2.githubusercontent.com/u/1044766?v=4","gravatar_id":"","url":"https://api.github.com/users/behrmann","html_url":"https://github.com/behrmann","followers_url":"https://api.github.com/users/behrmann/followers","following_url":"https://api.github.com/users/behrmann/following{/other_user}","gists_url":"https://api.github.com/users/behrmann/gists{/gist_id}","starred_url":"https://api.github.com/users/behrmann/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/behrmann/subscriptions","organizations_url":"https://api.github.com/users/behrmann/orgs","repos_url":"https://api.github.com/users/behrmann/repos","events_url":"https://api.github.com/users/behrmann/events{/privacy}","received_events_url":"https://api.github.com/users/behrmann/ ...

# %%
type(r.text)
# Out:
# str

# %%
import json

# json.loads: 將json格式資料轉換為字典
json.loads(r.text)
# Out:
# [{'id': '13146646538',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1044766,
#    'login': 'behrmann',
#    'display_login': 'behrmann',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/behrmann',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1044766?'},
#   'repo': {'id': 63237385,
#    'name': 'systemd/mkosi',
#    'url': 'https://api.github.com/repos/systemd/mkosi'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/systemd/mkosi/issues/490',
#     'repository_url': 'https://api.github.com/repos/systemd/mkosi',
#     'labels_url': 'https://api.github.com/repos/systemd/mkosi/issues/490/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/systemd/mkosi/issues/490/comments',
#     'events_url': 'https://api.github.com/repos/systemd/mkosi/issues/490/events',
#     'html_url': 'https://github.com/systemd/mkosi/pull/490',
#     'id': 672270824,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDYyMzM3NzIz',
#     'number': 490,
#     'title': 'Unified kernel images improvements',
#     'user': {'login': 'DaanDeMeyer',
#      'id': 9395011,
#      'node_id': 'MDQ6VXNlcjkzOTUwMTE=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/9395011?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DaanDeMeyer',
#      'html_url': 'https://github.com/DaanDeMeyer',
#      'followers_url': 'https://api.github.com/users/DaanDeMeyer/followers',
#      'following_url': 'https://api.github.com/users/DaanDeMeyer/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DaanDeMeyer/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DaanDeMeyer/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DaanDeMeyer/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DaanDeMeyer/orgs',
#      'repos_url': 'https://api.github.com/users/DaanDeMeyer/repos',
#      'events_url': 'https://api.github.com/users/DaanDeMeyer/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DaanDeMeyer/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 23,
#     'created_at': '2020-08-03T18:44:48Z',
#     'updated_at': '2020-08-08T11:08:51Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/systemd/mkosi/pulls/490',
#      'html_url': 'https://github.com/systemd/mkosi/pull/490',
#      'diff_url': 'https://github.com/systemd/mkosi/pull/490.diff',
#      'patch_url': 'https://github.com/systemd/mkosi/pull/490.patch'},
#     'body': "Doing the initial kernel installs with kernel-install and the rest with mkinitcpio is weird. Let's just use kernel-install all the time. Rest of the commits are simplification of the existing logic.\r\n\r\nI also want to add unified kernel images support for Arch but I want to accompany that with a flag to disable unified kernel images (which I really think should be the default but that breaks backwards compat)",
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/systemd/mkosi/issues/comments/670896166',
#     'html_url': 'https://github.com/systemd/mkosi/pull/490#issuecomment-670896166',
#     'issue_url': 'https://api.github.com/repos/systemd/mkosi/issues/490',
#     'id': 670896166,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY3MDg5NjE2Ng==',
#     'user': {'login': 'behrmann',
#      'id': 1044766,
#      'node_id': 'MDQ6VXNlcjEwNDQ3NjY=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1044766?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/behrmann',
#      'html_url': 'https://github.com/behrmann',
#      'followers_url': 'https://api.github.com/users/behrmann/followers',
#      'following_url': 'https://api.github.com/users/behrmann/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/behrmann/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/behrmann/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/behrmann/subscriptions',
#      'organizations_url': 'https://api.github.com/users/behrmann/orgs',
#      'repos_url': 'https://api.github.com/users/behrmann/repos',
#      'events_url': 'https://api.github.com/users/behrmann/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/behrmann/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-08-08T11:08:51Z',
#     'updated_at': '2020-08-08T11:08:51Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "Let's wait for CI, but this should be good to go. The path for where we install dracut files can still be changed in the future.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z',
#   'org': {'id': 1918868,
#    'login': 'systemd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/systemd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1918868?'}},
#  {'id': '13146646534',
#   'type': 'PushEvent',
#   'actor': {'id': 23476328,
#    'login': 'voldardard',
#    'display_login': 'voldardard',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/voldardard',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23476328?'},
#   'repo': {'id': 265477061,
#    'name': 'voldardard/glaze-toolbox',
#    'url': 'https://api.github.com/repos/voldardard/glaze-toolbox'},
#   'payload': {'push_id': 5500318934,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': '28b9d7c0848f916d06a3e04ee6a7de0b8b0b2704',
#    'before': '6a98771a70bbce41735a83330b59184ea3599c5f',
#    'commits': [{'sha': '28b9d7c0848f916d06a3e04ee6a7de0b8b0b2704',
#      'author': {'email': 'mbrugger@net4all.ch', 'name': 'MAthias Brugger'},
#      'message': 'debug saving to db',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/voldardard/glaze-toolbox/commits/28b9d7c0848f916d06a3e04ee6a7de0b8b0b2704'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646537',
#   'type': 'CreateEvent',
#   'actor': {'id': 52087885,
#    'login': 'ashok-sahu',
#    'display_login': 'ashok-sahu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ashok-sahu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52087885?'},
#   'repo': {'id': 286027414,
#    'name': 'ashok-sahu/chat-app',
#    'url': 'https://api.github.com/repos/ashok-sahu/chat-app'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646533',
#   'type': 'PushEvent',
#   'actor': {'id': 11969733,
#    'login': 'mohn93',
#    'display_login': 'mohn93',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mohn93',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11969733?'},
#   'repo': {'id': 285672954,
#    'name': 'mohn93/SwiftyIconGenerator',
#    'url': 'https://api.github.com/repos/mohn93/SwiftyIconGenerator'},
#   'payload': {'push_id': 5500318931,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a0554dc982c3f597e293d89d0248fcecb92ff426',
#    'before': '1929a226daaac4278a59b40e7e340be92102e3c2',
#    'commits': [{'sha': 'a0554dc982c3f597e293d89d0248fcecb92ff426',
#      'author': {'email': 'mohn93@gmail.com', 'name': 'Mohanned Binmiskeen'},
#      'message': 'fixed packages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mohn93/SwiftyIconGenerator/commits/a0554dc982c3f597e293d89d0248fcecb92ff426'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646529',
#   'type': 'PushEvent',
#   'actor': {'id': 113264,
#    'login': 'yath',
#    'display_login': 'yath',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yath',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/113264?'},
#   'repo': {'id': 201764649,
#    'name': 'yath/procyon-mirror',
#    'url': 'https://api.github.com/repos/yath/procyon-mirror'},
#   'payload': {'push_id': 5500318928,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/feature/issue-68-cast-removal',
#    'head': '69c80206828653540a332e8185b33fb2b33f2922',
#    'before': '69c80206828653540a332e8185b33fb2b33f2922',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646531',
#   'type': 'WatchEvent',
#   'actor': {'id': 23120302,
#    'login': 'AliAnilKocak',
#    'display_login': 'AliAnilKocak',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AliAnilKocak',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23120302?'},
#   'repo': {'id': 283888414,
#    'name': 'AhmedBeheiri/dart_commons',
#    'url': 'https://api.github.com/repos/AhmedBeheiri/dart_commons'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646525',
#   'type': 'WatchEvent',
#   'actor': {'id': 18545524,
#    'login': 'shanchuantian',
#    'display_login': 'shanchuantian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shanchuantian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18545524?'},
#   'repo': {'id': 12135779,
#    'name': 'coherentgraphics/cpdf-binaries',
#    'url': 'https://api.github.com/repos/coherentgraphics/cpdf-binaries'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z',
#   'org': {'id': 5366569,
#    'login': 'coherentgraphics',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/coherentgraphics',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5366569?'}},
#  {'id': '13146646519',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 232707436,
#    'name': 'sualehasif/sualehasif.github.io',
#    'url': 'https://api.github.com/repos/sualehasif/sualehasif.github.io'},
#   'payload': {'push_id': 5500318925,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ae1cf37caf32a5e24984e749f6c852d5b383fb0b',
#    'before': '9c11a3d3f8a80c1aa1fe3243c0e1cb324a13af32',
#    'commits': [{'sha': 'ae1cf37caf32a5e24984e749f6c852d5b383fb0b',
#      'author': {'email': 'alism@seas.upenn.edu',
#       'name': 'Ali Sulaiman Mohammad'},
#      'message': 'DataBot: Updated COVID data',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sualehasif/sualehasif.github.io/commits/ae1cf37caf32a5e24984e749f6c852d5b383fb0b'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646520',
#   'type': 'PushEvent',
#   'actor': {'id': 64999484,
#    'login': 'BotolMehedi',
#    'display_login': 'BotolMehedi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BotolMehedi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64999484?'},
#   'repo': {'id': 276418381,
#    'name': 'BotolMehedi/BotolMehedi.github.io',
#    'url': 'https://api.github.com/repos/BotolMehedi/BotolMehedi.github.io'},
#   'payload': {'push_id': 5500318923,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'da5f3f05b8a8d1c84493190df193d1e04c02ef3f',
#    'before': '58cc394a2ae7ff73aebfb6e8f9e225cfe7b9461c',
#    'commits': [{'sha': 'da5f3f05b8a8d1c84493190df193d1e04c02ef3f',
#      'author': {'email': '64999484+BotolMehedi@users.noreply.github.com',
#       'name': 'Mehedi Hasan Ariyan'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/BotolMehedi/BotolMehedi.github.io/commits/da5f3f05b8a8d1c84493190df193d1e04c02ef3f'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646517',
#   'type': 'PushEvent',
#   'actor': {'id': 16585714,
#    'login': 'sahilsk11',
#    'display_login': 'sahilsk11',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sahilsk11',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16585714?'},
#   'repo': {'id': 280159506,
#    'name': 'sahilsk11/ultron',
#    'url': 'https://api.github.com/repos/sahilsk11/ultron'},
#   'payload': {'push_id': 5500318924,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '02b8ac9229c238e2106dacc36f956572357e3e29',
#    'before': '2f9f4b83504e3c74272a1514cdbe8c41aa965e8b',
#    'commits': [{'sha': '02b8ac9229c238e2106dacc36f956572357e3e29',
#      'author': {'email': 'sahilkapur.a@gmail.com', 'name': 'Sahil Kapur'},
#      'message': 'final working versio',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sahilsk11/ultron/commits/02b8ac9229c238e2106dacc36f956572357e3e29'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646512',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 264846318,
#    'name': 'AdamZhang-0/AdamZhang-0.github.io',
#    'url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls/3',
#     'id': 465019434,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDY1MDE5NDM0',
#     'html_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io/pull/3',
#     'diff_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io/pull/3.diff',
#     'patch_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump rubyzip from 1.2.2 to 2.3.0',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [rubyzip](https://github.com/rubyzip/rubyzip) from 1.2.2 to 2.3.0.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/rubyzip/rubyzip/releases">rubyzip\'s releases</a>.</em></p>\n<blockquote>\n<h2>v2.3.0</h2>\n<ul>\n<li>Fix frozen string literal error <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/431">#431</a></li>\n<li>Set <code>OutputStream.write_buffer</code>\'s buffer to binmode <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/439">#439</a></li>\n<li>Upgrade rubocop and fix various linting complaints <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/437">#437</a> <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/440">#440</a></li>\n</ul>\n<p>Tooling:</p>\n<ul>\n<li>Add a <code>bin/console</code> script for development <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/420">#420</a></li>\n<li>Update rake requirement (development dependency only) to fix a security alert.</li>\n</ul>\n<h2>v2.2.0</h2>\n<ul>\n<li>Add support for decompression plugin gems <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/427">#427</a></li>\n</ul>\n<h2>v2.1.0</h2>\n<ul>\n<li>Fix (at least partially) the <code>restore_times</code> and <code>restore_permissions</code> options to <code>Zip::File.new</code> <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/413">#413</a>\n<ul>\n<li>Previously, neither option did anything, regardless of what it was set to. We have therefore defaulted them to <code>false</code> to preserve the current behavior, for the time being. If you have explicitly set either to <code>true</code>, it will now have an effect.</li>\n<li>Fix handling of UniversalTime (<code>mtime</code>, <code>atime</code>, <code>ctime</code>) fields. <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/421">#421</a></li>\n<li>Previously, <code>Zip::File</code> did not pass the options to <code>Zip::Entry</code> in some cases. <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/423">#423</a></li>\n<li>Note that <code>restore_times</code> in this release does nothing on Windows and only restores <code>mtime</code>, not <code>atime</code> or <code>ctime</code>.</li>\n</ul>\n</li>\n<li>Allow <code>Zip::File.open</code> to take an options hash like <code>Zip::File.new</code> <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/418">#418</a></li>\n<li>Always print warnings with <code>warn</code>, instead of a mix of <code>puts</code> and <code>warn</code> <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/416">#416</a></li>\n<li>Create temporary files in the system temporary directory instead of the directory of the zip file <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/411">#411</a></li>\n<li>Drop unused <code>tmpdir</code> requirement <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/411">#411</a></li>\n</ul>\n<p>Tooling</p>\n<ul>\n<li>Move CI to xenial and include jruby on JDK11 <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/419/files">#419</a></li>\n</ul>\n<h2>v2.0.0</h2>\n<p>Security</p>\n<ul>\n<li>Default the <code>validate_entry_sizes</code> option to <code>true</code>, so that callers can trust an entry\'s reported size when using <code>extract</code> <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pull/403">#403</a>\n<ul>\n<li>This option defaulted to <code>false</code> in 1.3.0 for backward compatibility, but it now defaults to <code>true</code>. If you are using an older version of ruby and can\'t yet upgrade to 2.x, you can still use 1.3.0 and set the option to <code>true</code>.</li>\n</ul>\n</li>\n</ul>\n<p>Tooling / Documentation</p>\n<ul>\n<li>Remove test files from the gem to avoid problems with antivirus detections on the test files <a href="https://github-redirect.dependabot.com/rubyzip/rubyzip/pul ...
#     'created_at': '2020-08-08T11:08:50Z',
#     'updated_at': '2020-08-08T11:08:50Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/statuses/245c39f46857740a597970ff40f68bda56b5a9db',
#     'head': {'label': 'AdamZhang-0:dependabot/bundler/rubyzip-2.3.0',
#      'ref': 'dependabot/bundler/rubyzip-2.3.0',
#      'sha': '245c39f46857740a597970ff40f68bda56b5a9db',
#      'user': {'login': 'AdamZhang-0',
#       'id': 65528554,
#       'node_id': 'MDQ6VXNlcjY1NTI4NTU0',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/65528554?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AdamZhang-0',
#       'html_url': 'https://github.com/AdamZhang-0',
#       'followers_url': 'https://api.github.com/users/AdamZhang-0/followers',
#       'following_url': 'https://api.github.com/users/AdamZhang-0/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AdamZhang-0/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AdamZhang-0/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AdamZhang-0/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AdamZhang-0/orgs',
#       'repos_url': 'https://api.github.com/users/AdamZhang-0/repos',
#       'events_url': 'https://api.github.com/users/AdamZhang-0/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AdamZhang-0/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 264846318,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjQ4NDYzMTg=',
#       'name': 'AdamZhang-0.github.io',
#       'full_name': 'AdamZhang-0/AdamZhang-0.github.io',
#       'private': False,
#       'owner': {'login': 'AdamZhang-0',
#        'id': 65528554,
#        'node_id': 'MDQ6VXNlcjY1NTI4NTU0',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/65528554?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AdamZhang-0',
#        'html_url': 'https://github.com/AdamZhang-0',
#        'followers_url': 'https://api.github.com/users/AdamZhang-0/followers',
#        'following_url': 'https://api.github.com/users/AdamZhang-0/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AdamZhang-0/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AdamZhang-0/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AdamZhang-0/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AdamZhang-0/orgs',
#        'repos_url': 'https://api.github.com/users/AdamZhang-0/repos',
#        'events_url': 'https://api.github.com/users/AdamZhang-0/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AdamZhang-0/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io',
#       'forks_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/forks',
#       'keys_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/teams',
#       'hooks_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/events',
#       'assignees_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/tags',
#       'blobs_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/languages',
#       'stargazers_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/subscription',
#       'commits_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/merges',
#       'archive_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/downloads',
#       'issues_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/deployments',
#       'created_at': '2020-05-18T06:21:10Z',
#       'updated_at': '2020-08-08T11:08:28Z',
#       'pushed_at': '2020-08-08T11:08:49Z',
#       'git_url': 'git://github.com/AdamZhang-0/AdamZhang-0.github.io.git',
#       'ssh_url': 'git@github.com:AdamZhang-0/AdamZhang-0.github.io.git',
#       'clone_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io.git',
#       'svn_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io',
#       'homepage': None,
#       'size': 1364,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'AdamZhang-0:master',
#      'ref': 'master',
#      'sha': '625d86d23361a5803f5a9b6f2b3d4369c50a272a',
#      'user': {'login': 'AdamZhang-0',
#       'id': 65528554,
#       'node_id': 'MDQ6VXNlcjY1NTI4NTU0',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/65528554?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AdamZhang-0',
#       'html_url': 'https://github.com/AdamZhang-0',
#       'followers_url': 'https://api.github.com/users/AdamZhang-0/followers',
#       'following_url': 'https://api.github.com/users/AdamZhang-0/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AdamZhang-0/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AdamZhang-0/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AdamZhang-0/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AdamZhang-0/orgs',
#       'repos_url': 'https://api.github.com/users/AdamZhang-0/repos',
#       'events_url': 'https://api.github.com/users/AdamZhang-0/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AdamZhang-0/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 264846318,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjQ4NDYzMTg=',
#       'name': 'AdamZhang-0.github.io',
#       'full_name': 'AdamZhang-0/AdamZhang-0.github.io',
#       'private': False,
#       'owner': {'login': 'AdamZhang-0',
#        'id': 65528554,
#        'node_id': 'MDQ6VXNlcjY1NTI4NTU0',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/65528554?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AdamZhang-0',
#        'html_url': 'https://github.com/AdamZhang-0',
#        'followers_url': 'https://api.github.com/users/AdamZhang-0/followers',
#        'following_url': 'https://api.github.com/users/AdamZhang-0/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AdamZhang-0/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AdamZhang-0/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AdamZhang-0/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AdamZhang-0/orgs',
#        'repos_url': 'https://api.github.com/users/AdamZhang-0/repos',
#        'events_url': 'https://api.github.com/users/AdamZhang-0/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AdamZhang-0/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io',
#       'forks_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/forks',
#       'keys_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/teams',
#       'hooks_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/events',
#       'assignees_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/tags',
#       'blobs_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/languages',
#       'stargazers_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/subscription',
#       'commits_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/merges',
#       'archive_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/downloads',
#       'issues_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/deployments',
#       'created_at': '2020-05-18T06:21:10Z',
#       'updated_at': '2020-08-08T11:08:28Z',
#       'pushed_at': '2020-08-08T11:08:49Z',
#       'git_url': 'git://github.com/AdamZhang-0/AdamZhang-0.github.io.git',
#       'ssh_url': 'git@github.com:AdamZhang-0/AdamZhang-0.github.io.git',
#       'clone_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io.git',
#       'svn_url': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io',
#       'homepage': None,
#       'size': 1364,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls/3'},
#      'html': {'href': 'https://github.com/AdamZhang-0/AdamZhang-0.github.io/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io/statuses/245c39f46857740a597970ff40f68bda56b5a9db'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646513',
#   'type': 'WatchEvent',
#   'actor': {'id': 16255580,
#    'login': 'ksboy',
#    'display_login': 'ksboy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ksboy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16255580?'},
#   'repo': {'id': 276279192,
#    'name': 'afatcoder/LeetcodeTop',
#    'url': 'https://api.github.com/repos/afatcoder/LeetcodeTop'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646503',
#   'type': 'PushEvent',
#   'actor': {'id': 61658739,
#    'login': 'snow922841',
#    'display_login': 'snow922841',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snow922841',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61658739?'},
#   'repo': {'id': 244173808,
#    'name': 'snow922841/m3ulist',
#    'url': 'https://api.github.com/repos/snow922841/m3ulist'},
#   'payload': {'push_id': 5500318911,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2dc967b51d5b1e8ff6cc8bef48ab518c4d541556',
#    'before': '5c15bd83fb39a6ffdd935f2b3d2a0d93968bc90f',
#    'commits': [{'sha': '2dc967b51d5b1e8ff6cc8bef48ab518c4d541556',
#      'author': {'email': '61658739+snow922841@users.noreply.github.com',
#       'name': 'snow922841'},
#      'message': 'delete a file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/snow922841/m3ulist/commits/2dc967b51d5b1e8ff6cc8bef48ab518c4d541556'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646504',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 60894542,
#    'login': 'vj-codes',
#    'display_login': 'vj-codes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vj-codes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60894542?'},
#   'repo': {'id': 279353671,
#    'name': 'fbdevelopercircles/open-source-edu-bot',
#    'url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot/issues/101',
#     'repository_url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot',
#     'labels_url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot/issues/101/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot/issues/101/comments',
#     'events_url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot/issues/101/events',
#     'html_url': 'https://github.com/fbdevelopercircles/open-source-edu-bot/pull/101',
#     'id': 675180044,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDY0NzQxOTUw',
#     'number': 101,
#     'title': 'fix: modified setup in Readme.md',
#     'user': {'login': 'vj-codes',
#      'id': 60894542,
#      'node_id': 'MDQ6VXNlcjYwODk0NTQy',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/60894542?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vj-codes',
#      'html_url': 'https://github.com/vj-codes',
#      'followers_url': 'https://api.github.com/users/vj-codes/followers',
#      'following_url': 'https://api.github.com/users/vj-codes/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vj-codes/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vj-codes/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vj-codes/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vj-codes/orgs',
#      'repos_url': 'https://api.github.com/users/vj-codes/repos',
#      'events_url': 'https://api.github.com/users/vj-codes/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vj-codes/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2201150683,
#       'node_id': 'MDU6TGFiZWwyMjAxMTUwNjgz',
#       'url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot/labels/CLA%20Signed',
#       'name': 'CLA Signed',
#       'color': '009900',
#       'default': False,
#       'description': 'This label is managed by the Facebook bot. Authors need to sign the CLA before a PR can be reviewed.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-08-07T18:01:30Z',
#     'updated_at': '2020-08-08T11:08:51Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot/pulls/101',
#      'html_url': 'https://github.com/fbdevelopercircles/open-source-edu-bot/pull/101',
#      'diff_url': 'https://github.com/fbdevelopercircles/open-source-edu-bot/pull/101.diff',
#      'patch_url': 'https://github.com/fbdevelopercircles/open-source-edu-bot/pull/101.patch'},
#     'body': '#### Is your pull request related to a problem? Please describe\r\nFixed issue #98\r\n\r\n#### Checklist\r\n- [ ] My code follows the code style of this project.\r\n- [ ] My change requires a change to the documentation.\r\n- [ ] I have updated the documentation accordingly.\r\n- [ ] I have read the **[CONTRIBUTING](https://github.com/fbdevelopercircles/open-source-edu-bot/blob/master/CONTRIBUTING.md)** document.\r\n- [ ] All new and existing tests passed.\r\n- [ ] The title of my pull request is a short description of the requested changes.\r\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot/issues/comments/670896153',
#     'html_url': 'https://github.com/fbdevelopercircles/open-source-edu-bot/pull/101#issuecomment-670896153',
#     'issue_url': 'https://api.github.com/repos/fbdevelopercircles/open-source-edu-bot/issues/101',
#     'id': 670896153,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY3MDg5NjE1Mw==',
#     'user': {'login': 'vj-codes',
#      'id': 60894542,
#      'node_id': 'MDQ6VXNlcjYwODk0NTQy',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/60894542?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/vj-codes',
#      'html_url': 'https://github.com/vj-codes',
#      'followers_url': 'https://api.github.com/users/vj-codes/followers',
#      'following_url': 'https://api.github.com/users/vj-codes/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/vj-codes/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/vj-codes/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/vj-codes/subscriptions',
#      'organizations_url': 'https://api.github.com/users/vj-codes/orgs',
#      'repos_url': 'https://api.github.com/users/vj-codes/repos',
#      'events_url': 'https://api.github.com/users/vj-codes/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/vj-codes/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-08-08T11:08:51Z',
#     'updated_at': '2020-08-08T11:08:51Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "> You can follow Syncing a fork section in this guide to update \n> \n> https://cshandbook.hoduchieu.tech/GitHandbook/GitCommands.html\n\nYeah @hoduchieu01 \nOnly half part got copied from my git bash window. I'll edit it soon:) ",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z',
#   'org': {'id': 38020791,
#    'login': 'fbdevelopercircles',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/fbdevelopercircles',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38020791?'}},
#  {'id': '13146646508',
#   'type': 'DeleteEvent',
#   'actor': {'id': 60312740,
#    'login': 'doob187',
#    'display_login': 'doob187',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/doob187',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60312740?'},
#   'repo': {'id': 286027295,
#    'name': 'doob187/PGClone-1',
#    'url': 'https://api.github.com/repos/doob187/PGClone-1'},
#   'payload': {'ref': 'multi-hd', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646499',
#   'type': 'CreateEvent',
#   'actor': {'id': 33515264,
#    'login': 's77007',
#    'display_login': 's77007',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/s77007',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33515264?'},
#   'repo': {'id': 286027413,
#    'name': 's77007/JHUCleaningData',
#    'url': 'https://api.github.com/repos/s77007/JHUCleaningData'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'JHU cleaning data assignment',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z'},
#  {'id': '13146646495',
#   'type': 'IssuesEvent',
#   'actor': {'id': 642064,
#    'login': 'enridaga',
#    'display_login': 'enridaga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/enridaga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/642064?'},
#   'repo': {'id': 31951952,
#    'name': 'the-open-university/basil',
#    'url': 'https://api.github.com/repos/the-open-university/basil'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/the-open-university/basil/issues/64',
#     'repository_url': 'https://api.github.com/repos/the-open-university/basil',
#     'labels_url': 'https://api.github.com/repos/the-open-university/basil/issues/64/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/the-open-university/basil/issues/64/comments',
#     'events_url': 'https://api.github.com/repos/the-open-university/basil/issues/64/events',
#     'html_url': 'https://github.com/the-open-university/basil/issues/64',
#     'id': 219167720,
#     'node_id': 'MDU6SXNzdWUyMTkxNjc3MjA=',
#     'number': 64,
#     'title': 'Does Basil support CONSTRUCT/UPDATE SPARQL queries?',
#     'user': {'login': 'barrynl',
#      'id': 26819305,
#      'node_id': 'MDQ6VXNlcjI2ODE5MzA1',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/26819305?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/barrynl',
#      'html_url': 'https://github.com/barrynl',
#      'followers_url': 'https://api.github.com/users/barrynl/followers',
#      'following_url': 'https://api.github.com/users/barrynl/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/barrynl/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/barrynl/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/barrynl/subscriptions',
#      'organizations_url': 'https://api.github.com/users/barrynl/orgs',
#      'repos_url': 'https://api.github.com/users/barrynl/repos',
#      'events_url': 'https://api.github.com/users/barrynl/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/barrynl/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 185251039,
#       'node_id': 'MDU6TGFiZWwxODUyNTEwMzk=',
#       'url': 'https://api.github.com/repos/the-open-university/basil/labels/question',
#       'name': 'question',
#       'color': 'cc317c',
#       'default': True,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2017-04-04T07:53:15Z',
#     'updated_at': '2020-08-08T11:08:50Z',
#     'closed_at': '2020-08-08T11:08:50Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'See title.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-08-08T11:08:51Z',
#   'org': {'id': 6358907,
#    'login': 'the-open-university',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/the-open-university',
# ...
#   'actor': {'id': 30047492,
#    'login': 'olekashiwa',
#    'display_login': 'olekashiwa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/olekashiwa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30047492?'},
#   'repo': {'id': 196414817,
#    'name': 'dappuniversity/starter_kit',
#    'url': 'https://api.github.com/repos/dappuniversity/starter_kit'},
#   'payload': {'forkee': {'id': 286027410,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyODYwMjc0MTA=',
#     'name': 'starter_kit',
#     'full_name': 'olekashiwa/starter_kit',
#     'private': False,
#     'owner': {'login': 'olekashiwa',
#      'id': 30047492,
#      'node_id': 'MDQ6VXNlcjMwMDQ3NDky',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/30047492?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/olekashiwa',
#      'html_url': 'https://github.com/olekashiwa',
#      'followers_url': 'https://api.github.com/users/olekashiwa/followers',
#      'following_url': 'https://api.github.com/users/olekashiwa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/olekashiwa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/olekashiwa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/olekashiwa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/olekashiwa/orgs',
#      'repos_url': 'https://api.github.com/users/olekashiwa/repos',
#      'events_url': 'https://api.github.com/users/olekashiwa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/olekashiwa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/olekashiwa/starter_kit',
#     'description': 'Start building full stack dApps fast with this starter kit!',
#     'fork': True,
#     'url': 'https://api.github.com/repos/olekashiwa/starter_kit',
#     'forks_url': 'https://api.github.com/repos/olekashiwa/starter_kit/forks',
#     'keys_url': 'https://api.github.com/repos/olekashiwa/starter_kit/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/olekashiwa/starter_kit/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/olekashiwa/starter_kit/teams',
#     'hooks_url': 'https://api.github.com/repos/olekashiwa/starter_kit/hooks',
#     'issue_events_url': 'https://api.github.com/repos/olekashiwa/starter_kit/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/olekashiwa/starter_kit/events',
#     'assignees_url': 'https://api.github.com/repos/olekashiwa/starter_kit/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/olekashiwa/starter_kit/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/olekashiwa/starter_kit/tags',
#     'blobs_url': 'https://api.github.com/repos/olekashiwa/starter_kit/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/olekashiwa/starter_kit/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/olekashiwa/starter_kit/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/olekashiwa/starter_kit/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/olekashiwa/starter_kit/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/olekashiwa/starter_kit/languages',
#     'stargazers_url': 'https://api.github.com/repos/olekashiwa/starter_kit/stargazers',
#     'contributors_url': 'https://api.github.com/repos/olekashiwa/starter_kit/contributors',
#     'subscribers_url': 'https://api.github.com/repos/olekashiwa/starter_kit/subscribers',
#     'subscription_url': 'https://api.github.com/repos/olekashiwa/starter_kit/subscription',
#     'commits_url': 'https://api.github.com/repos/olekashiwa/starter_kit/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/olekashiwa/starter_kit/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/olekashiwa/starter_kit/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/olekashiwa/starter_kit/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/olekashiwa/starter_kit/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/olekashiwa/starter_kit/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/olekashiwa/starter_kit/merges',
#     'archive_url': 'https://api.github.com/repos/olekashiwa/starter_kit/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/olekashiwa/starter_kit/downloads',
#     'issues_url': 'https://api.github.com/repos/olekashiwa/starter_kit/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/olekashiwa/starter_kit/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/olekashiwa/starter_kit/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/olekashiwa/starter_kit/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/olekashiwa/starter_kit/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/olekashiwa/starter_kit/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/olekashiwa/starter_kit/deployments',
#     'created_at': '2020-08-08T11:08:49Z',
#     'updated_at': '2020-08-08T05:05:22Z',
#     'pushed_at': '2020-08-06T08:38:32Z',
#     'git_url': 'git://github.com/olekashiwa/starter_kit.git',
#     'ssh_url': 'git@github.com:olekashiwa/starter_kit.git',
#     'clone_url': 'https://github.com/olekashiwa/starter_kit.git',
#     'svn_url': 'https://github.com/olekashiwa/starter_kit',
#     'homepage': None,
#     'size': 451,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-08-08T11:08:50Z',
#   'org': {'id': 35355951,
#    'login': 'dappuniversity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dappuniversity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35355951?'}},
#  {'id': '13146646473',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 264846318,
#    'name': 'AdamZhang-0/AdamZhang-0.github.io',
#    'url': 'https://api.github.com/repos/AdamZhang-0/AdamZhang-0.github.io'},
#   'payload': {'ref': 'dependabot/bundler/rubyzip-2.3.0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-08-08T11:08:50Z'},
#  {'id': '13146646466',
#   'type': 'PushEvent',
#   'actor': {'id': 11807600,
#    'login': 'enisdenjo',
#    'display_login': 'enisdenjo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/enisdenjo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11807600?'},
#   'repo': {'id': 283446239,
#    'name': 'enisdenjo/graphql-transport-ws',
#    'url': 'https://api.github.com/repos/enisdenjo/graphql-transport-ws'},
#   'payload': {'push_id': 5500318895,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/server',
#    'head': 'ff8d16574b95e697d9e97615478e3159e2c7d06c',
#    'before': '9697bdcec91bc8da6af5380bb6abfb995e606d47',
#    'commits': [{'sha': 'ff8d16574b95e697d9e97615478e3159e2c7d06c',
#      'author': {'email': 'badurinadenis@gmail.com', 'name': 'enisdenjo'},
#      'message': 'chore(deps): cleanup',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/enisdenjo/graphql-transport-ws/commits/ff8d16574b95e697d9e97615478e3159e2c7d06c'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:50Z'},
#  {'id': '13146646462',
#   'type': 'PushEvent',
#   'actor': {'id': 8465699,
#    'login': '5d2',
#    'display_login': '5d2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/5d2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8465699?'},
#   'repo': {'id': 281299666,
#    'name': '5d2/images',
#    'url': 'https://api.github.com/repos/5d2/images'},
#   'payload': {'push_id': 5500318893,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ad0e3d7e50651bddb76215e5db06fbcaec052a60',
#    'before': '31469c10ab0eed45a11f8f20520814a34661a6e3',
#    'commits': [{'sha': 'ad0e3d7e50651bddb76215e5db06fbcaec052a60',
#      'author': {'email': 'lxnan@live.com', 'name': '5d2'},
#      'message': 'commit from Mars',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/5d2/images/commits/ad0e3d7e50651bddb76215e5db06fbcaec052a60'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:50Z'},
#  {'id': '13146646460',
#   'type': 'PushEvent',
#   'actor': {'id': 50279075,
#    'login': 'mayanedms',
#    'display_login': 'mayanedms',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mayanedms',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50279075?'},
#   'repo': {'id': 184955400,
#    'name': 'mayan-edms/Mayan-EDMS',
#    'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS'},
#   'payload': {'push_id': 5500318884,
#    'size': 14,
#    'distinct_size': 0,
#    'ref': 'refs/heads/releases/all',
#    'head': '739fd31cf29707e463eb16c2e28fd670ad769449',
#    'before': 'bc8cb06075bf2333e7f9cca5e3318f8021c9183b',
#    'commits': [{'sha': '787a1a18f9c4b438a51b5eabede036a52e3e81a5',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Ensure tag events commit when using the REST API\n\nClose GitLab issue #850. Thanks to Olaf (@oohlaf) for the report.\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/787a1a18f9c4b438a51b5eabede036a52e3e81a5'},
#     {'sha': '5b337c1a7d6b965a8efbba0ffd5392a021ed801c',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Expose document type OCR settings to the REST API\n\nCloses GitLab issue #851. Thanks to Mike Mansell (@diamondq)\nfor the report.\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/5b337c1a7d6b965a8efbba0ffd5392a021ed801c'},
#     {'sha': 'da5a068ce5bb010be11a1254d1c89522e98af847',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Expose document type parsing settings on the API\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/da5a068ce5bb010be11a1254d1c89522e98af847'},
#     {'sha': '783337fb7d8577349fe148f8c508059275ac970d',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Add keyword arguments to the any_stream function\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/783337fb7d8577349fe148f8c508059275ac970d'},
#     {'sha': '57688b3321ad0568dd2af726d8536b58ced3ddbe',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Rename event_tag_remove to event_tag_removed\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/57688b3321ad0568dd2af726d8536b58ced3ddbe'},
#     {'sha': '344505467d8fae7d87d6ea4519fdb8164943de4f',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Support searching by workflow transition comment\n\nAdd support to search documents and document pages by their\nworkflow instance transition comments.\n\nCloses GitLab issue #846. Thanks to Sven Gaechter (@sgaechter)\nfor the report.\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/344505467d8fae7d87d6ea4519fdb8164943de4f'},
#     {'sha': '2c58057860dfe725c848561b83a57a3bb7573523',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Backport search app icon from version 3.5a1\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/2c58057860dfe725c848561b83a57a3bb7573523'},
#     {'sha': 'ac8079d99d5984e0ab82e7d507294f83c5f3873d',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Backport trashed document icon updates from 3.5a1\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/ac8079d99d5984e0ab82e7d507294f83c5f3873d'},
#     {'sha': '5f7565af37da02261c9a2a755c63ea704100132c',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Update translation files\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/5f7565af37da02261c9a2a755c63ea704100132c'},
#     {'sha': 'de71661be0e8769c34bdc3098668fb001d7c17bf',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Fix post embedded signing redirection URL\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/de71661be0e8769c34bdc3098668fb001d7c17bf'},
#     {'sha': '3c4cdda33fcc7c421df50105379bc85e05113453',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Update dependencies versions\n\n- Update Django from version 2.2.14 to 2.2.15.\n- Update Sphinx from version 3.0.3 to 3.0.4.\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/3c4cdda33fcc7c421df50105379bc85e05113453'},
#     {'sha': 'a805e25d4d3c24cb40eb55a571130deebec62df9',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Update release notes\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/a805e25d4d3c24cb40eb55a571130deebec62df9'},
#     {'sha': 'cb57debf2483e717cced4b5e4b2223bacb10e7f6',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Bump version to 3.4.13\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/cb57debf2483e717cced4b5e4b2223bacb10e7f6'},
#     {'sha': '739fd31cf29707e463eb16c2e28fd670ad769449',
#      'author': {'email': 'roberto.rosario@mayan-edms.com',
#       'name': 'Roberto Rosario'},
#      'message': 'Update build string\n\nSigned-off-by: Roberto Rosario <roberto.rosario@mayan-edms.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mayan-edms/Mayan-EDMS/commits/739fd31cf29707e463eb16c2e28fd670ad769449'}]},
#   'public': True,
#   'created_at': '2020-08-08T11:08:50Z',
#   'org': {'id': 50279080,
#    'login': 'mayan-edms',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mayan-edms',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50279080?'}}]

# %%
type(json.loads(r.text))
# Out:
# list

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H029","WaterLevel": 145.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H070","WaterLevel": 226.25},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H021","WaterLevel": 1.28},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H017","WaterLevel": 25.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2560H019","WaterLevel": 4.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1580H001","WaterLevel": 224.21},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H075","WaterLevel": 92.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H036","WaterLevel": 164.37},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2500H003","WaterLevel": 32.2},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H066","WaterLevel": 138.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H077","WaterLevel": 740.49},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1550H014","WaterLevel": 26.75},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1670H004","WaterLevel": 2.98},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H019","WaterLevel": 109.97},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H012","WaterLevel": 0.7},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H061","WaterLevel": 266.23},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H072","WaterLevel": 248.86},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H039","WaterLevel": 38.99},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1660H012","WaterLevel": 0.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2370H025","WaterLevel": 261.61},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H009","WaterLevel": 0.1},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H057","WaterLevel": 43.48},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H068","WaterLevel": 10.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H037","WaterLevel": 32.01},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H015","WaterLevel": 0.05},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2370H018","WaterLevel": 124.1},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H036","WaterLevel": 65.83},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1660H009","WaterLevel": 4.85},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1730H043","WaterLevel": 23.04},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2420H043","WaterLevel": 79.32},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1540H033","WaterLevel": 23.4},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H010","WaterLevel": 0.19},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H030","WaterLevel": 1.57},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H032","WaterLevel": 0.13},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1650H013","WaterLevel": 5.62},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1680H005","WaterLevel": 0.11},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "2200H026","WaterLevel": 106.73},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1350H031","WaterLevel": -0.15},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H040","WaterLevel": 1.76},{"RecordTime": "Dec 11, 2019 2:50:00 PM","StationIdentifier": "1630H018","WaterLevel": 10.01},{"RecordTime": "Dec 11, 2019 2:20:00 PM","StationIdentifier": "1630H027","WaterLevel": 26.14},{"RecordTime": "Dec 11, 2019 2:50:00 PM", ...

# %%
import json

json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': 32.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': 138.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': 740.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.75},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.98},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': 109.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H012',
#    'WaterLevel': 0.7},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': 266.23},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.86},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': 38.99},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H012',
#    'WaterLevel': 0.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.61},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': 43.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': 10.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 32.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': 0.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': 124.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.85},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': 23.04},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': 79.32},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': 23.4},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H010',
#    'WaterLevel': 0.19},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.57},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': 0.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.62},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': 0.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H026',
#    'WaterLevel': 106.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': -0.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': 1.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': 10.01},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.45},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.54},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': 0.03},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H029',
#    'WaterLevel': 175.97},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': 11.27},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.07},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 13.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H027',
#    'WaterLevel': 145.89},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': 752.39},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': 0.16},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': 48.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': 145.06},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': 0.59},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': 1068.94},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': 12.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.46},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': 95.66},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': 259.67},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': 78.22},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': 21.23},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': 187.7},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': 470.82},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': 50.6},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': 72.35},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': 220.79},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': 317.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': 19.39},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.41},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': 440.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H016',
#    'WaterLevel': 97.9},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': 15.74},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H075',
#    'WaterLevel': 346.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': 83.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': 622.43},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.68},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H015',
#    'WaterLevel': 50.08},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H054',
#    'WaterLevel': 704.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': 19.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': 0.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': 191.55},
#   {'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'StationIdentifier': '1140H106',
#    'WaterLevel': 49.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': 58.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': 54.19},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': 169.81},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': -1.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': 7.38},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': 12.12},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H099',
#    'WaterLevel': 263.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': 22.09},
#   {'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': 310.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
